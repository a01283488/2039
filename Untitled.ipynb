# %%
print('hola')
# Out:
# hola

# %%
nombre = 'My name'
print(nombre)
# Out:
# My name

# %%
nombre
# Out:
# 'My name'

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %pwd
# Out:
# '/home/jovyan'

# %%
# %ls
# Out:
# 00_00_binder.ipynb  README.md         session01/
# Cartwheeldata.csv   requirements.txt  Untitled.ipynb

# %%
import numpy as np
n=50
numeros_random = np.random.rand(n)
numeros_random
# Out:
# array([0.44292596, 0.76979952, 0.98776348, 0.4578728 , 0.23025038,
#        0.66813856, 0.48125019, 0.88918835, 0.43452394, 0.70366383,
#        0.94207814, 0.59745729, 0.05863188, 0.3784908 , 0.17636436,
#        0.73767298, 0.78091354, 0.70263379, 0.72037794, 0.72486564,
#        0.00258014, 0.2419865 , 0.43326713, 0.4464833 , 0.62809425,
#        0.10681463, 0.40878385, 0.9110287 , 0.07630353, 0.29736863,
#        0.96945691, 0.83400806, 0.59524966, 0.18505766, 0.87634782,
#        0.11313195, 0.40978311, 0.8001798 , 0.08192987, 0.48986203,
#        0.58319243, 0.8783153 , 0.42129729, 0.82736555, 0.22661293,
#        0.98451413, 0.44725054, 0.90630191, 0.41588397, 0.09821478])

# %%
import math


type(4) #enteros#
# Out:
# int

# %%
type(4.2) #me va a dar float que significa decimal#
# Out:
# float

# %%
type('my name') #str significa string y es texto#
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(2/5)
# Out:
# float

# %%
type(None)
# Out:
# NoneType

# %%
an_array = [1, 2, 3, 4, 10]
an_array
# Out:
# [1, 2, 3, 4, 10]

# %%
print(an_array)
# Out:
# [1, 2, 3, 4, 10]

# %%
suma = sum(an_array) #lo sume y lo gaurdé en la variable suma#
suma
# Out:
# 20

# %%
mean_an_array = suma/len(an_array)#promedio#

# %%
mean_an_array
# Out:
# 4.0

# %%
len(an_array) #longitud#
# Out:
# 5

# %%
6*10
# Out:
# 60

# %%
6*10**2 #6 por 10 al cuadrado#
# Out:
# 600

# %%
6*10**(-1) #6 por 10 a la menos 1#
# Out:
# 0.6000000000000001

# %%
math.pi #ya esta definida en la libreria math#
# Out:
# 3.141592653589793

# %%
type(math.pi) #es decimal pq es el numero#
# Out:
# float

# %%
type('math.pi') #con comillas es str#
# Out:
# str

# %%
otra_array =[2, math.pi, 3/5, 'a_str']
otra_array
# Out:
# [2, 3.141592653589793, 0.6, 'a_str']

# %%
sum(otra_array) #da error pq tiene un str, no se puede sumar#
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-72ecd7ad5339> in <module>
# ----> 1 sum(otra_array) #da error pq tiene un str, no se puede sumar#
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
#una funcion con if#
x=6
y=8
if x<y :
    print('{} es menor que {}' .format(x, y))
else:
    print('{} es menor que {}'.format(y,x))
# Out:
# 6 es menor que 8

# %%
my_list =[True, 6<5, 1==3, None is None]
my_list
# Out:
# [True, False, False, True]

# %%
for i in my_list:
    print('{} \t {}'.format(i, type(i)))
#bool es si es verdadero o falso#
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %%
for i in my_list:
    print(i, '\t', type(i)) #otra forma de escribirlos#
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %%
for i in my_list:
    print(i, '\t y su tipo es ', type(i))
# Out:
# True 	 y su tipo es  <class 'bool'>
# False 	 y su tipo es  <class 'bool'>
# False 	 y su tipo es  <class 'bool'>
# True 	 y su tipo es  <class 'bool'>

# %%
x = None
type(x)
# Out:
# NoneType

# %%
none_list = [None]*5
none_list
# Out:
# [None, None, None, None, None]

# %%
len(none_list)
# Out:
# 5

# %%
una_lista = ['pos_0', 'first', 'second', 'third', 'fourth', 'fifth']
una_lista
#el pos_0 es por que es posición cero#
# Out:
# ['pos_0', 'first', 'second', 'third', 'fourth', 'fifth']

# %%
len(una_lista)
# Out:
# 6

# %%
una_lista[2] #llamo a la posición 2 de la lista por que comienzan en cero#
# Out:
# 'second'

# %%
una_lista[3]
# Out:
# 'third'

# %%
una_lista[0:4] #no incluye la ultima posicion de lo solicitado#
# Out:
# ['pos_0', 'first', 'second', 'third']

# %%
una_lista[1:4] #solo del primero al tercero#
# Out:
# ['first', 'second', 'third']

# %%
una_lista[5]
# Out:
# 'fifth'

# %%
una_lista[-1]
# Out:
# 'fifth'

# %%
una_lista[-2:] #dejo abierto el final#
# Out:
# ['fourth', 'fifth']

# %%
una_lista[-4:-1] #no considera el ultimo, si quiero hasta el final mejor lo dejo abieto#
# Out:
# ['second', 'third', 'fourth']

# %%
una_lista[:] #sin principio ni final#
# Out:
# ['pos_0', 'first', 'second', 'third', 'fourth', 'fifth']
