# %%
import pandas as pd
import numpy as np

file_path ='Cartwheeldata.csv' #pongo l ubicación del archivo#
df = pd.read_csv(file_path) #lee el archivo#
df.head(3) #pone las primeras 3 lineas#
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7

# %%
df.tail(3) #ultimas 3 lineas#
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 22  23   25      M            2       N             0    70.0      68.0
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 22          82        Y              1      4
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
print(type(df.columns))
col_names_list = list(df.columns)
col_names_list.sort()
col_names_list
# Out:
# <class 'pandas.core.indexes.base.Index'>
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
df['Score'] #imprime en datos enteros con un solo corchete#
# Out:
# 0      7
# 1      8
# 2      7
# 3     10
# 4      4
# 5      3
# 6     10
# 7      9
# 8      5
# 9      8
# 10     6
# 11    10
# 12     6
# 13     4
# 14     9
# 15     6
# 16    10
# 17     5
# 18     3
# 19     8
# 20     2
# 21     8
# 22     4
# 23     5
# 24     3
# Name: Score, dtype: int64

# %%
df[['Score']] #imprime en dataframes cuando pongo doble corchete#
# Out:
#     Score
# 0       7
# 1       8
# 2       7
# 3      10
# 4       4
# 5       3
# 6      10
# 7       9
# 8       5
# 9       8
# 10      6
# 11     10
# 12      6
# 13      4
# 14      9
# 15      6
# 16     10
# 17      5
# 18      3
# 19      8
# 20      2
# 21      8
# 22      4
# 23      5
# 24      3

# %%
print(df[['Score']])
type(df[['Score']])
# Out:
#     Score
# 0       7
# 1       8
# 2       7
# 3      10
# 4       4
# 5       3
# 6      10
# 7       9
# 8       5
# 9       8
# 10      6
# 11     10
# 12      6
# 13      4
# 14      9
# 15      6
# 16     10
# 17      5
# 18      3
# 19      8
# 20      2
# 21      8
# 22      4
# 23      5
# 24      3
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df[['Complete', 'CompleteGroup',
       'Score']]
# Out:
#    Complete  CompleteGroup  Score
# 0         Y              1      7
# 1         Y              1      8
# 2         Y              1      7
# 3         Y              1     10
# 4         N              0      4
# 5         N              0      3
# 6         Y              1     10
# 7         Y              1      9
# 8         N              0      5
# 9         Y              1      8
# 10        Y              1      6
# 11        Y              1     10
# 12        Y              1      6
# 13        Y              1      4
# 14        Y              1      9
# 15        Y              1      6
# 16        N              0     10
# 17        Y              1      5
# 18        Y              1      3
# 19        Y              1      8
# 20        N              0      2
# 21        Y              1      8
# 22        Y              1      4
# 23        Y              1      5
# 24        N              0      3

# %%
df.loc[:,['Complete','Score']] #row start, row end : column start , column end#
# Out:
#    Complete  Score
# 0         Y      7
# 1         Y      8
# 2         Y      7
# 3         Y     10
# 4         N      4
# 5         N      3
# 6         Y     10
# 7         Y      9
# 8         N      5
# 9         Y      8
# 10        Y      6
# 11        Y     10
# 12        Y      6
# 13        Y      4
# 14        Y      9
# 15        Y      6
# 16        N     10
# 17        Y      5
# 18        Y      3
# 19        Y      8
# 20        N      2
# 21        Y      8
# 22        Y      4
# 23        Y      5
# 24        N      3

# %%
df.loc[2:4,['Complete','Score']]
# Out:
#   Complete  Score
# 2        Y      7
# 3        Y     10
# 4        N      4

# %%
df.iloc[:5] #row start:row end, column start:column end#
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.iloc[2:5,2:5] #recordar que comienza en cero y no incluye el ultimo#
# Out:
#   Gender  GenderGroup Glasses
# 2      F            1       Y
# 3      F            1       N
# 4      M            2       N

# %%
df.iloc[2:5, [4,7]]
# Out:
#   Glasses  Wingspan
# 2       Y      64.0
# 3       N      63.0
# 4       N      75.0

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df.Gender.unique() #para conocer los tipos#
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.Height.unique()
# Out:
# array([62.  , 66.  , 64.  , 73.  , 75.  , 65.  , 74.  , 63.  , 69.5 ,
#        62.75, 61.5 , 71.  , 70.  , 68.  , 69.  ])

# %%
df.groupby(['Gender', 'GenderGroup']).size()
# Out:
# Gender  GenderGroup
# F       1              12
# M       2              13
# dtype: int64

# %%
df.groupby(['Height', 'Gender']).size()
# Out:
# Height  Gender
# 61.50   F         2
# 62.00   F         2
# 62.75   F         1
# 63.00   F         1
# 64.00   F         1
# 65.00   F         3
# 66.00   F         1
#         M         1
# 68.00   F         1
# 69.00   M         2
# 69.50   M         1
# 70.00   M         2
# 71.00   M         2
# 73.00   M         2
# 74.00   M         1
# 75.00   M         2
# dtype: int64

# %%
dtc = pd.read_excel('session01/datasets/Canada.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-44-72d5ba5a1d8c> in <module>
# ----> 1 dtc = pd.read_excel('session01/datasets/Canada.xlsx')
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# ...
