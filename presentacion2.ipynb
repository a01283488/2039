# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('NEWYOKRDATA.csv')
df.head(2)
# Out:
#       CAMIS                 DBA       BORO BUILDING         STREET  ZIPCODE  \
# 0  50014362            URUBAMBA     Queens     8620       37TH AVE  11372.0
# 1  41626598  SAL'S FAMILY PIZZA  Manhattan      384  BROOME STREET  10013.0
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  7186722224            Peruvian        04/09/19
# 1  2129250440               Pizza      09/19/2018
#
#                                             ACTION  ... RECORD DATE  \
# 0  Violations were cited in the following area(s).  ...  08/28/2021
# 1                Establishment re-opened by DOHMH.  ...  08/28/2021
#
#                                      INSPECTION TYPE   Latitude  Longitude  \
# 0              Cycle Inspection / Initial Inspection  40.750154 -73.880319
# 1  Administrative Miscellaneous / Reopening Inspe...  40.720402 -73.996573
#
#   Community Board Council District Census Tract        BIN         BBL   NTA
# ...

# %%
#%ls

# %%
df.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL',
#        'NTA'],
#       dtype='object')

# %%
data = df.sample (n=100,
                 random_state=20)

# %%
line_data=data.groupby('CUISINE DESCRIPTION')['SCORE'].mean().reset_index()
line_data
# Out:
#                CUISINE DESCRIPTION      SCORE
# 0                          African  51.000000
# 1                         American  17.400000
# 2                  Bagels/Pretzels   9.000000
# 3         Bakery Products/Desserts  38.500000
# 4                         Barbecue  12.000000
# 5                Bottled Beverages   6.000000
# 6                        Caribbean  41.000000
# 7                          Chicken  10.000000
# 8                          Chinese  18.571429
# 9                 Chinese/Japanese  22.000000
# 10                      Coffee/Tea  22.666667
# 11                          Donuts  10.000000
# 12                          French  14.500000
# 13                 Frozen Desserts  13.000000
# 14                          German  19.000000
# 15                      Hamburgers  13.000000
# 16                          Indian  16.500000
# 17                      Indonesian  43.000000
# 18                         Italian  22.333333
# ...

# %%
fig=go.Figure(data=go.Scatter(x=line_data['CUISINE DESCRIPTION'],
                             y=line_data['SCORE'],
                             mode = 'lines',
                             marker = dict(color='green')
                             )
             )
fig.show()
# Out:
# <div>                            <div id="a234920f-36a2-42f8-9dd7-96139d357f56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a234920f-36a2-42f8-9dd7-96139d357f56")) {                    Plotly.newPlot(                        "a234920f-36a2-42f8-9dd7-96139d357f56",                        [{"marker":{"color":"green"},"mode":"lines","type":"scatter","x":["African","American","Bagels/Pretzels","Bakery Products/Desserts","Barbecue","Bottled Beverages","Caribbean","Chicken","Chinese","Chinese/Japanese","Coffee/Tea","Donuts","French","Frozen Desserts","German","Hamburgers","Indian","Indonesian","Italian","Japanese","Jewish/Kosher","Juice, Smoothies, Fruit Salads","Korean","Latin American","Mexican","Middle Eastern","Pakistani","Peruvian","Pizza","Russia
# ...

# %%
fig=px.bar(line_data,
          x='CUISINE DESCRIPTION',
          y='SCORE',
          title='Bar chart')
fig.show()
# Out:
# <div>                            <div id="96532af3-416d-4661-9f6f-a8fb72f0aceb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96532af3-416d-4661-9f6f-a8fb72f0aceb")) {                    Plotly.newPlot(                        "96532af3-416d-4661-9f6f-a8fb72f0aceb",                        [{"alignmentgroup":"True","hovertemplate":"CUISINE DESCRIPTION=%{x}<br>SCORE=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["African","American","Bagels/Pretzels","Bakery Products/Desserts","Barbecue","Bottled Beverages","Caribbean","Chicken","Chinese","Chinese/Japanese","Coffee/Tea","Donuts","French","Frozen Desserts",
# ...

# %%
#regresio multiple 

import statsmodels.api as sm
model = sm.OLS.from_formula('BIN~SCORE', 
                           data = df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    BIN   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.248
# Date:                Thu, 09 Sep 2021   Prob (F-statistic):              0.266
# Time:                        05:10:51   Log-Likelihood:                -2143.5
# No. Observations:                 138   AIC:                             4291.
# Df Residuals:                     136   BIC:                             4297.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.354e+06   2.08e+05     11.339      0.000    1.94e+06    2.76e+06
# ...
